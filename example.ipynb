# %%
from AlgoDinamicWithVal import AlgoSeqDynamicWithValidation

# %%
import random

# %% [markdown]
# # С валидатором

# %%
def custom_validator(chain):
    random_float = random.random()
    if (random_float > 0.6):
        return False
    else:
        return True

algo = AlgoSeqDynamicWithValidation(custom_validator)
a_seq = "ACCDACCDDD"
b_seq = "CBBBBFFF"
steps, operations, distance = algo.run(a_seq, b_seq)

if steps is None:
    print("Не найден валидный путь преобразования")
else:
    print(f"Найден путь! Расстояние: {distance}")
    print(f"Операции: {operations}")
    print(f"Шаги преобразования: {steps}")
    print("Последовательность преобразования:")
    for i, step in enumerate(steps):
        print(f"{i}: {step}")
# Out:
# Найден путь! Расстояние: 10
# Операции: [('delete', 'A'), ('replace', 'C', 'B'), ('delete', 'D'), ('insert', 'B'), ('delete', 'A'), ('replace', 'C', 'B'), ('replace', 'C', 'B'), ('replace', 'D', 'F'), ('replace', 'D', 'F'), ('replace', 'D', 'F')]
# Шаги преобразования: ['ACCDACCDDD', 'CCDACCDDD', 'CBDACCDDD', 'CBACCDDD', 'CBBACCDDD', 'CBBCCDDD', 'CBBBCDDD', 'CBBBBDDD', 'CBBBBFDD', 'CBBBBFFD', 'CBBBBFFF']
# Последовательность преобразования:
# 0: ACCDACCDDD
# 1: CCDACCDDD
# 2: CBDACCDDD
# 3: CBACCDDD
# 4: CBBACCDDD
# 5: CBBCCDDD
# 6: CBBBCDDD
# 7: CBBBBDDD
# 8: CBBBBFDD
# 9: CBBBBFFD
# 10: CBBBBFFF

# %%
import time
start_time = time.time()

# Симуляция unflodable 
def custom_validator(chain):
    random_float = random.random()
    if (random_float > 0.7):
        return False
    else:
        return True

algo = AlgoSeqDynamicWithValidation(custom_validator)
a_seq = "ACDEFGHK"
b_seq = "MKTAYIAKQRQISFVKSHFS"
steps, operations, distance = algo.run(a_seq, b_seq)

if steps is None:
    print("Не найден валидный путь преобразования")
else:
    print(f"Найден путь! Расстояние: {distance}")
    print(f"Операции: {operations}")
    print(f"Шаги преобразования: {steps}")
    print("Последовательность преобразования:")
    for i, step in enumerate(steps):
        print(f"{i}: {step}")
end_time = time.time()
execution_time = end_time - start_time
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 12
#       9     else:
#      10         return True
# ---> 12 algo = AlgoSeqDynamicWithValidation(custom_validator)
#      13 a_seq = "ACDEFGHK"
#      14 b_seq = "MKTAYIAKQRQISFVKSHFS"
#
# NameError: name 'AlgoSeqDynamicWithValidation' is not defined

# %%
execution_time # Долго считает
# Out:
# 65.91450548171997

# %% [markdown]
# # Жадный

# %%
from AlgoDynamic import AlgoSeqDynamic

# %%
algo = AlgoSeqDynamic()
start_time = time.time()
steps, operations, min_distance = algo.run('ACDEFGHK', 'MKTAYIAKQRQISFVKSHFS')
end_time = time.time()
execution_time = end_time - start_time

# %%
execution_time
# Out:
# 0.0002033710479736328

# %%
steps
# Out:
# ['ACDEFGHK',
#  'MACDEFGHK',
#  'MKACDEFGHK',
#  'MKTACDEFGHK',
#  'MKTAACDEFGHK',
#  'MKTAYACDEFGHK',
#  'MKTAYIACDEFGHK',
#  'MKTAYIAKCDEFGHK',
#  'MKTAYIAKQCDEFGHK',
#  'MKTAYIAKQRCDEFGHK',
#  'MKTAYIAKQRQDEFGHK',
#  'MKTAYIAKQRQIEFGHK',
#  'MKTAYIAKQRQISFGHK',
#  'MKTAYIAKQRQISFVGHK',
#  'MKTAYIAKQRQISFVKGHK',
#  'MKTAYIAKQRQISFVKSHK',
#  'MKTAYIAKQRQISFVKSHFK',
#  'MKTAYIAKQRQISFVKSHFS']

# %%
# !python -m pip install -e ./cath_nn_lev_lib/
# Out:
# Obtaining file:///home/main/vega_algo/datasetgradualstep/cath_nn_lev_lib
#   Installing build dependencies ... done
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... done
#   Preparing editable metadata (pyproject.toml) ... done
# Building wheels for collected packages: cath_nn_lev
#   Building editable for cath_nn_lev (pyproject.toml) ... done
#   Created wheel for cath_nn_lev: filename=cath_nn_lev-0.1.0-0.editable-cp310-cp310-linux_x86_64.whl size=3895 sha256=034affc16f23b28a1e4bf162b019367e7b8a7b9827d50337c06e3d9739be54c3
#   Stored in directory: /tmp/pip-ephem-wheel-cache-ztso9fyc/wheels/e8/c7/30/a8164f6ddaef97cd74fbae1a02355baff4061bff60f0c96edb
# Successfully built cath_nn_lev
# Installing collected packages: cath_nn_lev
#   Attempting uninstall: cath_nn_lev
#     Found existing installation: cath_nn_lev 0.1.0
#     Uninstalling cath_nn_lev-0.1.0:
#       Successfully uninstalled cath_nn_lev-0.1.0
# Successfully installed cath_nn_lev-0.1.0

# %%
import sys, site
print(sys.executable)
print(sys.path[:5])
print(site.getsitepackages())

# %%
import cath_nn_lev
print('Запуск алгоритма')
stats = cath_nn_lev.find_pairs(
    "pdb_sequences.fasta",
    "pairs_1_layer.tsv",
    k=12,
    M=500,
    threads=24,
    strict=0,
    write_directed_path="directed.tsv",
)
print(stats)
# Out:
# Запуск алгоритма
# {'n_sequences': 34653, 'total_kmers': 4983346, 'k': 12, 'M': 500, 'df_max': 2000, 'threads_used': 24, 'time_read_s': 0.02245568499984074, 'time_index_s': 0.512000738000097, 'time_query_s': 34.04276769500029, 'time_total_s': 34.60560527300004}

# %%
# !python3 make_layer2.py pairs_1_layer.tsv pdb_sequences.fasta pdb_sequences_layer_2.fasta
# Out:
# [make_layer2] pairs lines read: 34349
# [make_layer2] unique idx1: 1187
# [make_layer2] fasta records written: 1187
# [make_layer2] done

# %%
print('Запуск алгоритма')
stats = cath_nn_lev.find_pairs(
    "pdb_sequences_layer_2.fasta",
    "pairs_2_layer.tsv",
    k=12,
    M=500,
    threads=24,
    strict=0,
    write_directed_path="directed2.tsv",
)
print(stats)
# Out:
# Запуск алгоритма
# {'n_sequences': 1187, 'total_kmers': 181343, 'k': 12, 'M': 500, 'df_max': 2000, 'threads_used': 24, 'time_read_s': 0.000977738999608846, 'time_index_s': 0.013555686000472633, 'time_query_s': 1.3071125839996967, 'time_total_s': 1.32268620800005}

# %%
# !python3 make_layer2.py pairs_2_layer.tsv pdb_sequences_layer_2.fasta pdb_sequences_layer_3.fasta
# Out:
# [make_layer2] pairs lines read: 1150
# [make_layer2] unique idx1: 436
# [make_layer2] fasta records written: 436
# [make_layer2] done

# %%
print('Запуск алгоритма')
stats = cath_nn_lev.find_pairs(
    "pdb_sequences_layer_3.fasta",
    "pairs_3_layer.tsv",
    k=12,
    M=500,
    threads=24,
    strict=0,
    write_directed_path="directed3.tsv",
)
print(stats)
# Out:
# Запуск алгоритма
# {'n_sequences': 436, 'total_kmers': 59333, 'k': 12, 'M': 435, 'df_max': 2000, 'threads_used': 24, 'time_read_s': 0.0004247029992257012, 'time_index_s': 0.003941240000131074, 'time_query_s': 0.36172352300036437, 'time_total_s': 0.3666085759996349}

# %%
# !python3 make_layer2.py pairs_3_layer.tsv pdb_sequences_layer_3.fasta pdb_sequences_layer_4.fasta
# Out:
# [make_layer2] pairs lines read: 417
# [make_layer2] unique idx1: 285
# [make_layer2] fasta records written: 285
# [make_layer2] done

# %%
print('Запуск алгоритма')
stats = cath_nn_lev.find_pairs(
    "pdb_sequences_layer_4.fasta",
    "pairs_4_layer.tsv",
    k=12,
    M=500,
    threads=24,
    strict=0,
    write_directed_path="directed4.tsv",
)
print(stats)
# Out:
# Запуск алгоритма
# {'n_sequences': 285, 'total_kmers': 36669, 'k': 12, 'M': 284, 'df_max': 2000, 'threads_used': 24, 'time_read_s': 0.00031518600007984787, 'time_index_s': 0.002388975999565446, 'time_query_s': 0.14619787599986012, 'time_total_s': 0.14928232700003718}

# %%
# !python3 make_layer2.py pairs_4_layer.tsv pdb_sequences_layer_4.fasta pdb_sequences_layer_5.fasta
# Out:
# [make_layer2] pairs lines read: 275
# [make_layer2] unique idx1: 201
# [make_layer2] fasta records written: 201
# [make_layer2] done

# %%
print('Запуск алгоритма')
stats = cath_nn_lev.find_pairs(
    "pdb_sequences_layer_5.fasta",
    "pairs_5_layer.tsv",
    k=12,
    M=500,
    threads=24,
    strict=0,
    write_directed_path="directed5.tsv",
)
print(stats)
# Out:
# Запуск алгоритма
# {'n_sequences': 201, 'total_kmers': 25070, 'k': 12, 'M': 200, 'df_max': 2000, 'threads_used': 24, 'time_read_s': 0.0002533759998186724, 'time_index_s': 0.001497148999987985, 'time_query_s': 0.07904030400004558, 'time_total_s': 0.08109813299961388}

# %%
# !python run_layers.py --start 4 --k 12 --M 500 --threads 24 --strict 0
# Out:
# [run_layers] building layer 5 from pairs_4_layer.tsv -> pdb_sequences_layer_5.fasta
# [make_layer2] pairs lines read: 275
# [make_layer2] unique idx1: 201
# [make_layer2] fasta records written: 201
# [run_layers] layer 5 fasta records: 201
# [run_layers] запуск алгоритма
# {'n_sequences': 201, 'total_kmers': 25070, 'k': 12, 'M': 200, 'df_max': 2000, 'threads_used': 24, 'time_read_s': 0.00010342099994886667, 'time_index_s': 0.0017272170007345267, 'time_query_s': 0.07385911499932263, 'time_total_s': 0.07605935799983854}
# [run_layers] pairs in layer 5: 195
# [run_layers] building layer 6 from pairs_5_layer.tsv -> pdb_sequences_layer_6.fasta
# [make_layer2] pairs lines read: 195
# [make_layer2] unique idx1: 157
# [make_layer2] fasta records written: 157
# [run_layers] layer 6 fasta records: 157
# [run_layers] запуск алгоритма
# {'n_sequences': 157, 'total_kmers': 19952, 'k': 12, 'M': 156, 'df_max': 2000, 'threads_used': 24, 'time_read_s': 8.584199986216845e-05, 'time_index_s': 0.001268322000214539, 'time_query_s': 0.05621254299967404, 'time_total_s': 0.057832741000311216}
# [run_layers] pairs in layer 6: 154
# [run_layers] building layer 7 from pairs_6_layer.tsv -> pdb_sequences_layer_7.fasta
# [make_layer2] pairs lines read: 154
# [make_layer2] unique idx1: 121
# [make_layer2] fasta records written: 121
# [run_layers] layer 7 fasta records: 121
# [run_layers] запуск алгоритма
# {'n_sequences': 121, 'total_kmers': 14954, 'k': 12, 'M': 120, 'df_max': 2000, 'threads_used': 24, 'time_read_s': 6.285000017669518e-05, 'time_index_s': 0.000925868000194896, 'time_query_s': 0.037707112999669334, 'time_total_s': 0.038938964000408305}
# [run_layers] pairs in layer 7: 119
# [run_layers] building layer 8 from pairs_7_layer.tsv -> pdb_sequences_layer_8.fasta
# [make_layer2] pairs lines read: 119
# [make_layer2] unique idx1: 95
# [make_layer2] fasta records written: 95
# [run_layers] layer 8 fasta records: 95
# [run_layers] запуск алгоритма
# {'n_sequences': 95, 'total_kmers': 11778, 'k': 12, 'M': 94, 'df_max': 2000, 'threads_used': 24, 'time_read_s': 5.5573999816260766e-05, 'time_index_s': 0.0007123109999156441, 'time_query_s': 0.02097566599968559, 'time_total_s': 0.021920555999713542}
# [run_layers] pairs in layer 8: 93
# [run_layers] building layer 9 from pairs_8_layer.tsv -> pdb_sequences_layer_9.fasta
# [make_layer2] pairs lines read: 93
# [make_layer2] unique idx1: 76
# [make_layer2] fasta records written: 76
# [run_layers] layer 9 fasta records: 76
# [run_layers] запуск алгоритма
# {'n_sequences': 76, 'total_kmers': 9252, 'k': 12, 'M': 75, 'df_max': 2000, 'threads_used': 24, 'time_read_s': 5.028199939260958e-05, 'time_index_s': 0.0005223369998930139, 'time_query_s': 0.01597950799987302, 'time_total_s': 0.016720733999136428}
# [run_layers] pairs in layer 9: 74
# [run_layers] building layer 10 from pairs_9_layer.tsv -> pdb_sequences_layer_10.fasta
# [make_layer2] pairs lines read: 74
# [make_layer2] unique idx1: 59
# [make_layer2] fasta records written: 59
# [run_layers] layer 10 fasta records: 59
# [run_layers] запуск алгоритма
# {'n_sequences': 59, 'total_kmers': 7139, 'k': 12, 'M': 58, 'df_max': 2000, 'threads_used': 24, 'time_read_s': 4.662399987864774e-05, 'time_index_s': 0.00037920700015092734, 'time_query_s': 0.012671249000050011, 'time_total_s': 0.01322783200066624}
# [run_layers] pairs in layer 10: 57
# [run_layers] building layer 11 from pairs_10_layer.tsv -> pdb_sequences_layer_11.fasta
# [make_layer2] pairs lines read: 57
# [make_layer2] unique idx1: 41
# [make_layer2] fasta records written: 41
# [run_layers] layer 11 fasta records: 41
# [run_layers] запуск алгоритма
# {'n_sequences': 41, 'total_kmers': 5381, 'k': 12, 'M': 40, 'df_max': 2000, 'threads_used': 24, 'time_read_s': 4.0921000618254766e-05, 'time_index_s': 0.0002824709999913466, 'time_query_s': 0.006294017000072927, 'time_total_s': 0.006774319000214746}
# [run_layers] pairs in layer 11: 40
# [run_layers] building layer 12 from pairs_11_layer.tsv -> pdb_sequences_layer_12.fasta
# [make_layer2] pairs lines read: 40
# [make_layer2] unique idx1: 32
# [make_layer2] fasta records written: 32
# [run_layers] layer 12 fasta records: 32
# [run_layers] запуск алгоритма
# {'n_sequences': 32, 'total_kmers': 4552, 'k': 12, 'M': 31, 'df_max': 2000, 'threads_used': 24, 'time_read_s': 3.6391000321600586e-05, 'time_index_s': 0.00023010399945633253, 'time_query_s': 0.005128484000124445, 'time_total_s': 0.005542437999793037}
# [run_layers] pairs in layer 12: 31
# [run_layers] building layer 13 from pairs_12_layer.tsv -> pdb_sequences_layer_13.fasta
# [make_layer2] pairs lines read: 31
# [make_layer2] unique idx1: 24
# [make_layer2] fasta records written: 24
# [run_layers] layer 13 fasta records: 24
# [run_layers] запуск алгоритма
# {'n_sequences': 24, 'total_kmers': 3745, 'k': 12, 'M': 23, 'df_max': 2000, 'threads_used': 24, 'time_read_s': 3.5378999200474937e-05, 'time_index_s': 0.00019528700067894533, 'time_query_s': 0.0031299399997806177, 'time_total_s': 0.003478047999124101}
# [run_layers] pairs in layer 13: 23
# [run_layers] building layer 14 from pairs_13_layer.tsv -> pdb_sequences_layer_14.fasta
# [make_layer2] pairs lines read: 23
# [make_layer2] unique idx1: 22
# [make_layer2] fasta records written: 22
# [run_layers] layer 14 fasta records: 22
# [run_layers] запуск алгоритма
# {'n_sequences': 22, 'total_kmers': 3568, 'k': 12, 'M': 21, 'df_max': 2000, 'threads_used': 22, 'time_read_s': 3.283300065959338e-05, 'time_index_s': 0.0001952659995367867, 'time_query_s': 0.003554648999852361, 'time_total_s': 0.0038997190004010918}
# [run_layers] pairs in layer 14: 21
# [run_layers] building layer 15 from pairs_14_layer.tsv -> pdb_sequences_layer_15.fasta
# [make_layer2] pairs lines read: 21
# [make_layer2] unique idx1: 16
# [make_layer2] fasta records written: 16
# [run_layers] layer 15 fasta records: 16
# [run_layers] запуск алгоритма
# {'n_sequences': 16, 'total_kmers': 2767, 'k': 12, 'M': 15, 'df_max': 2000, 'threads_used': 16, 'time_read_s': 3.005700000358047e-05, 'time_index_s': 0.00013417999980447348, 'time_query_s': 0.003521435000038764, 'time_total_s': 0.003812484999798471}
# [run_layers] pairs in layer 15: 15
# [run_layers] building layer 16 from pairs_15_layer.tsv -> pdb_sequences_layer_16.fasta
# [make_layer2] pairs lines read: 15
# [make_layer2] unique idx1: 12
# [make_layer2] fasta records written: 12
# [run_layers] layer 16 fasta records: 12
# [run_layers] запуск алгоритма
# {'n_sequences': 12, 'total_kmers': 2062, 'k': 12, 'M': 11, 'df_max': 2000, 'threads_used': 12, 'time_read_s': 3.289300002506934e-05, 'time_index_s': 0.00010997600020345999, 'time_query_s': 0.001940242999808106, 'time_total_s': 0.0021966550002616714}
# [run_layers] pairs in layer 16: 11
# [run_layers] building layer 17 from pairs_16_layer.tsv -> pdb_sequences_layer_17.fasta
# [make_layer2] pairs lines read: 11
# [make_layer2] unique idx1: 10
# [make_layer2] fasta records written: 10
# [run_layers] layer 17 fasta records: 10
# [run_layers] запуск алгоритма
# {'n_sequences': 10, 'total_kmers': 1523, 'k': 12, 'M': 9, 'df_max': 2000, 'threads_used': 10, 'time_read_s': 2.7471000066725537e-05, 'time_index_s': 7.049800024105934e-05, 'time_query_s': 0.0008641200001875404, 'time_total_s': 0.001067825000063749}
# [run_layers] pairs in layer 17: 9
# [run_layers] building layer 18 from pairs_17_layer.tsv -> pdb_sequences_layer_18.fasta
# [make_layer2] pairs lines read: 9
# [make_layer2] unique idx1: 8
# [make_layer2] fasta records written: 8
# [run_layers] layer 18 fasta records: 8
# [run_layers] запуск алгоритма
# {'n_sequences': 8, 'total_kmers': 1321, 'k': 12, 'M': 7, 'df_max': 2000, 'threads_used': 8, 'time_read_s': 2.6899999284069054e-05, 'time_index_s': 6.0786000176449306e-05, 'time_query_s': 0.0008259350006483146, 'time_total_s': 0.0010206399992966908}
# [run_layers] pairs in layer 18: 7
# [run_layers] building layer 19 from pairs_18_layer.tsv -> pdb_sequences_layer_19.fasta
# [make_layer2] pairs lines read: 7
# [make_layer2] unique idx1: 7
# [make_layer2] fasta records written: 7
# [run_layers] layer 19 fasta records: 7
# [run_layers] запуск алгоритма
# {'n_sequences': 7, 'total_kmers': 1195, 'k': 12, 'M': 6, 'df_max': 2000, 'threads_used': 7, 'time_read_s': 2.6249000256939325e-05, 'time_index_s': 5.4831999477755744e-05, 'time_query_s': 0.0006717910000588745, 'time_total_s': 0.0008569239998905687}
# [run_layers] pairs in layer 19: 6
# [run_layers] building layer 20 from pairs_19_layer.tsv -> pdb_sequences_layer_20.fasta
# [make_layer2] pairs lines read: 6
# [make_layer2] unique idx1: 5
# [make_layer2] fasta records written: 5
# [run_layers] layer 20 fasta records: 5
# [run_layers] запуск алгоритма
# {'n_sequences': 5, 'total_kmers': 854, 'k': 12, 'M': 4, 'df_max': 2000, 'threads_used': 5, 'time_read_s': 2.5425999410799704e-05, 'time_index_s': 3.7184000575507525e-05, 'time_query_s': 0.00041537699962646, 'time_total_s': 0.0005887849993087002}
# [run_layers] pairs in layer 20: 4
# [run_layers] building layer 21 from pairs_20_layer.tsv -> pdb_sequences_layer_21.fasta
# [make_layer2] pairs lines read: 4
# [make_layer2] unique idx1: 4
# [make_layer2] fasta records written: 4
# [run_layers] layer 21 fasta records: 4
# [run_layers] запуск алгоритма
# {'n_sequences': 4, 'total_kmers': 766, 'k': 12, 'M': 3, 'df_max': 2000, 'threads_used': 4, 'time_read_s': 2.5235999601136427e-05, 'time_index_s': 3.323500004626112e-05, 'time_query_s': 0.0003533389999574865, 'time_total_s': 0.0005186079997656634}
# [run_layers] pairs in layer 21: 3
# [run_layers] building layer 22 from pairs_21_layer.tsv -> pdb_sequences_layer_22.fasta
# [make_layer2] pairs lines read: 3
# [make_layer2] unique idx1: 3
# [make_layer2] fasta records written: 3
# [run_layers] layer 22 fasta records: 3
# [run_layers] запуск алгоритма
# {'n_sequences': 3, 'total_kmers': 643, 'k': 12, 'M': 2, 'df_max': 2000, 'threads_used': 3, 'time_read_s': 2.5296999410784338e-05, 'time_index_s': 2.6329000320401974e-05, 'time_query_s': 0.00037754799996037036, 'time_total_s': 0.0006593279995286139}
# [run_layers] pairs in layer 22: 2
# [run_layers] building layer 23 from pairs_22_layer.tsv -> pdb_sequences_layer_23.fasta
# [make_layer2] pairs lines read: 2
# [make_layer2] unique idx1: 2
# [make_layer2] fasta records written: 2
# [run_layers] layer 23 fasta records: 2
# [run_layers] запуск алгоритма
# {'n_sequences': 2, 'total_kmers': 469, 'k': 12, 'M': 1, 'df_max': 2000, 'threads_used': 2, 'time_read_s': 2.9736000215052627e-05, 'time_index_s': 2.1206999917922076e-05, 'time_query_s': 0.000257701000009547, 'time_total_s': 0.00041545300064171897}
# [run_layers] pairs in layer 23: 1
# [run_layers] stop: pairs_23_layer.tsv has 1 line(s)

# %%
# !python run_pair_validations.py \
    --layers-dir layer_outputs \
    --out-dir validation_outputs \
    --validator-prob 0.5 \
    --seed 234 \
    --threads 28 \
    --backend processes \
    --progress-interval 2
# Out:
# [run_pair_validations] layer 10: reading fasta layer_outputs/pdb_sequences_layer_10.fasta
# [run_pair_validations] layer 10: processing pairs layer_outputs/pairs_10_layer.tsv
# [layer 10] 1/57 | 26.29 pairs/s | ETA 2.1s
# [layer 10] 46/57 | 20.97 pairs/s | ETA 0.5s
# [layer 10] 55/57 | 11.48 pairs/s | ETA 0.2s
# [layer 10] 56/57 | 5.29 pairs/s | ETA 0.2s
# [layer 10] 57/57 | 4.99 pairs/s | ETA 0.0s
# [run_pair_validations] layer 10: done (processed=57, found=1, not_found=56, timeout=0, invalid_index=0, skipped=0)
# [run_pair_validations] layer 11: reading fasta layer_outputs/pdb_sequences_layer_11.fasta
# [run_pair_validations] layer 11: processing pairs layer_outputs/pairs_11_layer.tsv
# [layer 11] 1/40 | 28.21 pairs/s | ETA 1.4s
# [layer 11] 36/40 | 17.48 pairs/s | ETA 0.2s
# [layer 11] 39/40 | 5.76 pairs/s | ETA 0.2s
# [layer 11] 40/40 | 2.84 pairs/s | ETA 0.0s
# [run_pair_validations] layer 11: done (processed=40, found=0, not_found=40, timeout=0, invalid_index=0, skipped=0)
# [run_pair_validations] layer 12: reading fasta layer_outputs/pdb_sequences_layer_12.fasta
# [run_pair_validations] layer 12: processing pairs layer_outputs/pairs_12_layer.tsv
# [layer 12] 1/31 | 26.34 pairs/s | ETA 1.1s
# [layer 12] 30/31 | 13.07 pairs/s | ETA 0.1s
# [layer 12] 31/31 | 6.38 pairs/s | ETA 0.0s
# [run_pair_validations] layer 12: done (processed=31, found=0, not_found=31, timeout=0, invalid_index=0, skipped=0)
# [run_pair_validations] layer 13: reading fasta layer_outputs/pdb_sequences_layer_13.fasta
# [run_pair_validations] layer 13: processing pairs layer_outputs/pairs_13_layer.tsv
# [layer 13] 1/23 | 31.27 pairs/s | ETA 0.7s
# [layer 13] 22/23 | 9.46 pairs/s | ETA 0.1s
# [layer 13] 23/23 | 7.61 pairs/s | ETA 0.0s
# [run_pair_validations] layer 13: done (processed=23, found=0, not_found=23, timeout=0, invalid_index=0, skipped=0)
# [run_pair_validations] layer 14: reading fasta layer_outputs/pdb_sequences_layer_14.fasta
# [run_pair_validations] layer 14: processing pairs layer_outputs/pairs_14_layer.tsv
# [layer 14] 1/21 | 30.65 pairs/s | ETA 0.7s
# [layer 14] 16/21 | 6.71 pairs/s | ETA 0.7s
# [layer 14] 21/21 | 4.11 pairs/s | ETA 0.0s
# [run_pair_validations] layer 14: done (processed=21, found=0, not_found=21, timeout=0, invalid_index=0, skipped=0)
# [run_pair_validations] layer 15: reading fasta layer_outputs/pdb_sequences_layer_15.fasta
# [run_pair_validations] layer 15: processing pairs layer_outputs/pairs_15_layer.tsv
# [layer 15] 1/15 | 30.65 pairs/s | ETA 0.5s
# [layer 15] 12/15 | 5.27 pairs/s | ETA 0.6s
# [layer 15] 15/15 | 2.94 pairs/s | ETA 0.0s
# [run_pair_validations] layer 15: done (processed=15, found=0, not_found=15, timeout=0, invalid_index=0, skipped=0)
# [run_pair_validations] layer 16: reading fasta layer_outputs/pdb_sequences_layer_16.fasta
# [run_pair_validations] layer 16: processing pairs layer_outputs/pairs_16_layer.tsv
# [layer 16] 1/11 | 32.29 pairs/s | ETA 0.3s
# [layer 16] 10/11 | 4.60 pairs/s | ETA 0.2s
# [layer 16] 11/11 | 0.46 pairs/s | ETA 0.0s
# [run_pair_validations] layer 16: done (processed=11, found=0, not_found=11, timeout=0, invalid_index=0, skipped=0)
# [run_pair_validations] layer 17: reading fasta layer_outputs/pdb_sequences_layer_17.fasta
# [run_pair_validations] layer 17: processing pairs layer_outputs/pairs_17_layer.tsv
# [layer 17] 1/9 | 31.45 pairs/s | ETA 0.3s
# [layer 17] 9/9 | 4.02 pairs/s | ETA 0.0s
# [run_pair_validations] layer 17: done (processed=9, found=0, not_found=9, timeout=0, invalid_index=0, skipped=0)
# [run_pair_validations] layer 18: reading fasta layer_outputs/pdb_sequences_layer_18.fasta
# [run_pair_validations] layer 18: processing pairs layer_outputs/pairs_18_layer.tsv
# [layer 18] 1/7 | 27.28 pairs/s | ETA 0.2s
# [layer 18] 5/7 | 2.33 pairs/s | ETA 0.9s
# [layer 18] 7/7 | 3.00 pairs/s | ETA 0.0s
# [run_pair_validations] layer 18: done (processed=7, found=0, not_found=7, timeout=0, invalid_index=0, skipped=0)
# [run_pair_validations] layer 19: reading fasta layer_outputs/pdb_sequences_layer_19.fasta
# [run_pair_validations] layer 19: processing pairs layer_outputs/pairs_19_layer.tsv
# [layer 19] 1/6 | 15.77 pairs/s | ETA 0.3s
# [layer 19] 4/6 | 1.84 pairs/s | ETA 1.1s

# %%
import random
print('pre import c lib')
import datasetgradualstep_c as dsc
print('post import c lib')
pairs_path = "layer_outputs/pairs_1_layer.tsv"
fasta_path = "layer_outputs/pdb_sequences_layer_1.fasta"
print('read fasta')
# читаем FASTA в массив
seqs = []
with open(fasta_path, "r", encoding="utf-8") as f:
  cur = None
  for line in f:
      if line.startswith(">"):
          if cur is not None:
              seqs.append(cur)
          cur = ""
      else:
          cur += line.strip()
  if cur is not None:
      seqs.append(cur)
print('readed fasta')
# читаем все пары и выбираем случайную
pairs = []
print('reading file')
with open(pairs_path, "r", encoding="utf-8") as f:
  for line in f:
      if not line.strip():
          continue
      cols = line.rstrip("\n").split("\t")
      if len(cols) < 4:
          continue
      i1 = int(cols[2])
      i2 = int(cols[3])
      pairs.append((i1, i2))
print('readed file')
if not pairs:
  raise RuntimeError("Файл пар пуст")
print('random choice')
idx1, idx2 = random.choice(pairs)
a_seq = seqs[idx1]
b_seq = seqs[idx2]

print(f"Выбрана пара idx1={idx1} idx2={idx2}")

def custom_validator(chain):
  return random.random() <= 0.6
print('Start')
steps, operations, distance = dsc.algo_seq_dynamic_with_validation_run(
  a_seq, b_seq, validator=custom_validator
)
print('Completed')

if steps is None:
  print("Не найден валидный путь преобразования")
else:
  print(f"Найден путь! Расстояние: {distance}")
  print(f"Операции: {operations}")
  print(f"Шаги преобразования: {steps}")
  print("Последовательность преобразования:")
  for i, step in enumerate(steps):
      print(f"{i}: {step}")
# Out:
# pre import c lib
# post import c lib
# read fasta
# readed fasta
# reading file
# readed file
# random choice
# Выбрана пара idx1=118 idx2=8945
# Start
# Completed
# Не найден валидный путь преобразования
