# %%
# !python setup.py build_ext --inplace
# Out:
# running build_ext
# building 'datasetgradualstep_c._core' extension
# clang -Wno-unused-result -Wsign-compare -Wunreachable-code -DNDEBUG -fwrapv -O2 -Wall -fPIC -O2 -isystem /usr/local/Caskroom/miniconda/base/envs/vector/include -arch x86_64 -I/usr/local/Caskroom/miniconda/base/envs/vector/include -fPIC -O2 -isystem /usr/local/Caskroom/miniconda/base/envs/vector/include -arch x86_64 -I/usr/local/Caskroom/miniconda/base/envs/vector/include/python3.9 -c datasetgradualstep_c.c -o build/temp.macosx-10.15-x86_64-cpython-39/datasetgradualstep_c.o
# datasetgradualstep_c.c:1718:1: warning: function 'search_paths' is not needed and will not be emitted [-Wunneeded-internal-declaration]
# search_paths(SearchCtx *ctx, Py_ssize_t i, Py_ssize_t j, Py_ssize_t depth) {
# ^
# 1 warning generated.
# clang -bundle -undefined dynamic_lookup -Wl,-rpath,/usr/local/Caskroom/miniconda/base/envs/vector/lib -L/usr/local/Caskroom/miniconda/base/envs/vector/lib -L/usr/local/Caskroom/miniconda/base/envs/vector/lib -Wl,-rpath,/usr/local/Caskroom/miniconda/base/envs/vector/lib -L/usr/local/Caskroom/miniconda/base/envs/vector/lib build/temp.macosx-10.15-x86_64-cpython-39/datasetgradualstep_c.o -o build/lib.macosx-10.15-x86_64-cpython-39/datasetgradualstep_c/_core.cpython-39-darwin.so
# copying build/lib.macosx-10.15-x86_64-cpython-39/datasetgradualstep_c/_core.cpython-39-darwin.so -> .

# %%
import datasetgradualstep_c as dsc

# %%
dir(dsc)
# Out:
# ['__all__',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__path__',
#  '__spec__',
#  '_core',
#  'algo_seq_dynamic_run',
#  'algo_seq_dynamic_with_validation_run']

# %%
import random

# %% [markdown]
# # С валидатором

# %%
def custom_validator(chain):
    random_float = random.random()
    if (random_float > 0.8):
        return False
    else:
        return True

a_seq = "ACCDACCDDD"
b_seq = "DDDCCADCCA"
steps, operations, distance = dsc.algo_seq_dynamic_with_validation_run(a_seq, b_seq, validator=custom_validator)

if steps is None:
    print("Не найден валидный путь преобразования")
else:
    print(f"Найден путь! Расстояние: {distance}")
    print(f"Операции: {operations}")
    print(f"Шаги преобразования: {steps}")
    print("Последовательность преобразования:")
    for i, step in enumerate(steps):
        print(f"{i}: {step}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 10
#       8 a_seq = "ACCDACCDDD"
#       9 b_seq = "DDDCCADCCA"
# ---> 10 steps, operations, distance = dsc.algo_seq_dynamic_with_validation_run(a_seq, b_seq, validator=custom_validator)
#      12 if steps is None:
#      13     print("Не найден валидный путь преобразования")
#
# NameError: name 'dsc' is not defined

# %%
import time
start_time = time.time()

# Симуляция unflodable 
def custom_validator(chain):
    random_float = random.random()
    if (random_float > 0.5):
        return False
    else:
        return True

a_seq = "ACDEFGHK"
b_seq = "MKTAYIAKQRQISFVKSHFS"
steps, operations, distance = dsc.algo_seq_dynamic_with_validation_run(a_seq, b_seq, validator=custom_validator)

if steps is None:
    print("Не найден валидный путь преобразования")
else:
    print(f"Найден путь! Расстояние: {distance}")
    print(f"Операции: {operations}")
    print(f"Шаги преобразования: {steps}")
    print("Последовательность преобразования:")
    for i, step in enumerate(steps):
        print(f"{i}: {step}")
end_time = time.time()
execution_time = end_time - start_time
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[129], line 14
#      12 a_seq = "ACDEFGHK"
#      13 b_seq = "MKTAYIAKQRQISFVKSHFS"
# ---> 14 steps, operations, distance = dsc.algo_seq_dynamic_with_validation_run(a_seq, b_seq, validator=custom_validator)
#      16 if steps is None:
#      17     print("Не найден валидный путь преобразования")
#
# RuntimeError: Insert index out of range

# %%
b_seq == steps[-1]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[130], line 1
# ----> 1 b_seq == steps[-1]
#
# TypeError: 'NoneType' object is not subscriptable

# %% [markdown]
# # Жадный

# %%
from AlgoDynamic import AlgoSeqDynamic

# %%
algo = AlgoSeqDynamic()
start_time = time.time()
steps, operations, min_distance = algo.run('ACDEFGHK', 'MKTAYIAKQRQISFVKSHFS')
end_time = time.time()
execution_time = end_time - start_time

# %%
execution_time
# Out:
# 0.0004239082336425781

# %%
steps
# Out:
# ['ACDEFGHK',
#  'MACDEFGHK',
#  'MKACDEFGHK',
#  'MKTACDEFGHK',
#  'MKTAACDEFGHK',
#  'MKTAYACDEFGHK',
#  'MKTAYIACDEFGHK',
#  'MKTAYIAKCDEFGHK',
#  'MKTAYIAKQCDEFGHK',
#  'MKTAYIAKQRCDEFGHK',
#  'MKTAYIAKQRQDEFGHK',
#  'MKTAYIAKQRQIEFGHK',
#  'MKTAYIAKQRQISFGHK',
#  'MKTAYIAKQRQISFVGHK',
#  'MKTAYIAKQRQISFVKGHK',
#  'MKTAYIAKQRQISFVKSHK',
#  'MKTAYIAKQRQISFVKSHFK',
#  'MKTAYIAKQRQISFVKSHFS']
