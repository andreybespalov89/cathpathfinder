# %%
from AlgoDinamicWithVal import AlgoSeqDynamicWithValidation

# %%
import random

# %% [markdown]
# # С валидатором

# %%
def custom_validator(chain):
    random_float = random.random()
    if (random_float > 0.6):
        return False
    else:
        return True

algo = AlgoSeqDynamicWithValidation(custom_validator)
a_seq = "ACCDACCDDD"
b_seq = "CBBBBFFF"
steps, operations, distance = algo.run(a_seq, b_seq)

if steps is None:
    print("Не найден валидный путь преобразования")
else:
    print(f"Найден путь! Расстояние: {distance}")
    print(f"Операции: {operations}")
    print(f"Шаги преобразования: {steps}")
    print("Последовательность преобразования:")
    for i, step in enumerate(steps):
        print(f"{i}: {step}")
# Out:
# Найден путь! Расстояние: 10
# Операции: [('delete', 'A'), ('replace', 'C', 'B'), ('delete', 'D'), ('insert', 'B'), ('delete', 'A'), ('replace', 'C', 'B'), ('replace', 'C', 'B'), ('replace', 'D', 'F'), ('replace', 'D', 'F'), ('replace', 'D', 'F')]
# Шаги преобразования: ['ACCDACCDDD', 'CCDACCDDD', 'CBDACCDDD', 'CBACCDDD', 'CBBACCDDD', 'CBBCCDDD', 'CBBBCDDD', 'CBBBBDDD', 'CBBBBFDD', 'CBBBBFFD', 'CBBBBFFF']
# Последовательность преобразования:
# 0: ACCDACCDDD
# 1: CCDACCDDD
# 2: CBDACCDDD
# 3: CBACCDDD
# 4: CBBACCDDD
# 5: CBBCCDDD
# 6: CBBBCDDD
# 7: CBBBBDDD
# 8: CBBBBFDD
# 9: CBBBBFFD
# 10: CBBBBFFF

# %%
import time
start_time = time.time()

# Симуляция unflodable 
def custom_validator(chain):
    random_float = random.random()
    if (random_float > 0.7):
        return False
    else:
        return True

algo = AlgoSeqDynamicWithValidation(custom_validator)
a_seq = "ACDEFGHK"
b_seq = "MKTAYIAKQRQISFVKSHFS"
steps, operations, distance = algo.run(a_seq, b_seq)

if steps is None:
    print("Не найден валидный путь преобразования")
else:
    print(f"Найден путь! Расстояние: {distance}")
    print(f"Операции: {operations}")
    print(f"Шаги преобразования: {steps}")
    print("Последовательность преобразования:")
    for i, step in enumerate(steps):
        print(f"{i}: {step}")
end_time = time.time()
execution_time = end_time - start_time
# Out:
# Найден путь! Расстояние: 20
# Операции: [('insert', 'M'), ('insert', 'K'), ('insert', 'T'), ('insert', 'A'), ('replace', 'A', 'Y'), ('insert', 'I'), ('replace', 'C', 'A'), ('insert', 'K'), ('insert', 'Q'), ('replace', 'D', 'R'), ('insert', 'Q'), ('insert', 'I'), ('insert', 'S'), ('replace', 'E', 'F'), ('insert', 'V'), ('insert', 'K'), ('replace', 'F', 'S'), ('replace', 'G', 'H'), ('replace', 'H', 'F'), ('replace', 'K', 'S')]
# Шаги преобразования: ['ACDEFGHK', 'MACDEFGHK', 'MKACDEFGHK', 'MKTACDEFGHK', 'MKTAACDEFGHK', 'MKTAYCDEFGHK', 'MKTAYICDEFGHK', 'MKTAYIADEFGHK', 'MKTAYIAKDEFGHK', 'MKTAYIAKQDEFGHK', 'MKTAYIAKQREFGHK', 'MKTAYIAKQRQEFGHK', 'MKTAYIAKQRQIEFGHK', 'MKTAYIAKQRQISEFGHK', 'MKTAYIAKQRQISFFGHK', 'MKTAYIAKQRQISFVFGHK', 'MKTAYIAKQRQISFVKFGHK', 'MKTAYIAKQRQISFVKSGHK', 'MKTAYIAKQRQISFVKSHHK', 'MKTAYIAKQRQISFVKSHFK', 'MKTAYIAKQRQISFVKSHFS']
# Последовательность преобразования:
# 0: ACDEFGHK
# 1: MACDEFGHK
# 2: MKACDEFGHK
# 3: MKTACDEFGHK
# 4: MKTAACDEFGHK
# 5: MKTAYCDEFGHK
# 6: MKTAYICDEFGHK
# 7: MKTAYIADEFGHK
# 8: MKTAYIAKDEFGHK
# 9: MKTAYIAKQDEFGHK
# 10: MKTAYIAKQREFGHK
# 11: MKTAYIAKQRQEFGHK
# 12: MKTAYIAKQRQIEFGHK
# 13: MKTAYIAKQRQISEFGHK
# 14: MKTAYIAKQRQISFFGHK
# 15: MKTAYIAKQRQISFVFGHK
# 16: MKTAYIAKQRQISFVKFGHK
# 17: MKTAYIAKQRQISFVKSGHK
# 18: MKTAYIAKQRQISFVKSHHK
# 19: MKTAYIAKQRQISFVKSHFK
# 20: MKTAYIAKQRQISFVKSHFS

# %%
execution_time # Долго считает
# Out:
# 65.91450548171997

# %% [markdown]
# # Жадный

# %%
from AlgoDynamic import AlgoSeqDynamic

# %%
algo = AlgoSeqDynamic()
start_time = time.time()
steps, operations, min_distance = algo.run('ACDEFGHK', 'MKTAYIAKQRQISFVKSHFS')
end_time = time.time()
execution_time = end_time - start_time

# %%
execution_time
# Out:
# 0.0002033710479736328

# %%
steps
# Out:
# ['ACDEFGHK',
#  'MACDEFGHK',
#  'MKACDEFGHK',
#  'MKTACDEFGHK',
#  'MKTAACDEFGHK',
#  'MKTAYACDEFGHK',
#  'MKTAYIACDEFGHK',
#  'MKTAYIAKCDEFGHK',
#  'MKTAYIAKQCDEFGHK',
#  'MKTAYIAKQRCDEFGHK',
#  'MKTAYIAKQRQDEFGHK',
#  'MKTAYIAKQRQIEFGHK',
#  'MKTAYIAKQRQISFGHK',
#  'MKTAYIAKQRQISFVGHK',
#  'MKTAYIAKQRQISFVKGHK',
#  'MKTAYIAKQRQISFVKSHK',
#  'MKTAYIAKQRQISFVKSHFK',
#  'MKTAYIAKQRQISFVKSHFS']
